# %% [markdown]
# **S'entrainer** sur [CodEx](https://codex.forge.apps.education.fr) et conserver une trace de vos réalisations ci-dessous

# %%
VOYELLES = ["a", "e", "i", "o", "u", "y"]

def dentiste(texte):
    dent= ''
    for lettre in texte :
        if lettre in VOYELLES :
            dent+=lettre
    return dent

# %%
dentiste("j'ai mal")
# Out:
# 'aia'

# %%
def correspond(mot_complet, mot_a_trous):
    resul=''
    for i in mot_a_trous : 
        if i == "." :
            
            

    if resul == mot_complet :
        print(True)
    else :
        print(False)

# %%
correspond("INFORMATIQUE", "INFO.MA.IQUE")
